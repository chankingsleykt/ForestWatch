# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Get and Format Data

# %%
def prepare_data(data, year):
    data = data.rename(columns=lambda x: x[2:] if x[1]=='_' else x)
    data['year'] = year
    data = data.sample(frac=1)
    return data

# %%
appalachia_train_sets = [prepare_data(pd.read_csv(f"datasets/post_pivot/plus_one/expanded_class/types/temperate/appalachia_train_{year}.csv"), year) for year in range(2022, 2025)]
appalachia_train = pd.concat(appalachia_train_sets, axis=0)

carpathians_train_sets = [prepare_data(pd.read_csv(f"datasets/post_pivot/plus_one/expanded_class/types/temperate/carpathians_train_{year}.csv"), year) for year in range(2022, 2025)]
carpathians_train = pd.concat(carpathians_train_sets, axis=0)

fareast_train_sets = [prepare_data(pd.read_csv(f"datasets/post_pivot/plus_one/expanded_class/types/temperate/fareast_train_{year}.csv"), year) for year in range(2022, 2025)]
fareast_train = pd.concat(fareast_train_sets, axis=0)

train_set = pd.concat([appalachia_train, carpathians_train, fareast_train], axis=0)
train_set = train_set.sample(frac=1)
train_set = train_set.sort_values(by='year')
print(train_set.head())
# print(train_set.groupby('year')['class'].count())
# Out:
#      system:index  NBR_delta_lag4  NBR_lag4  NDMI_delta_lag4  NDMI_lag4  \
# 1945     1_4945_0        0.042272  0.352579         0.044210   0.258925
# 5364     2_2364_0       -0.049376  0.152137        -0.037743   0.015310
# 5518     2_2518_0       -0.028036  0.293012        -0.105671   0.168504
# 2923     1_5923_0       -0.045409  0.229670        -0.025680   0.128179
# 1490     1_4490_0        0.061876  0.171508         0.065837   0.040565
#
#       NDVI_delta_lag4  NDVI_lag4  SR_B4_delta_lag4  SR_B4_lag4  \
# 1945         0.018710   0.384057            -383.0      8059.0
# 5364         0.015739   0.261546            -681.5      8550.0
# 5518         0.033903   0.332727           -1379.0      8624.5
# 2923        -0.040654   0.278140            -565.5      8117.5
# 1490         0.040316   0.258751            -905.5      8799.0
#
#       SR_B5_delta_lag4  ...  NDVI_lag0  SR_B4_lag0  SR_B5_lag0  SR_B6_lag0  \
# 1945             -52.5  ...   0.365347      8442.0     18161.5     11741.0
# 5364            -642.5  ...   0.245808      9231.5     15249.0     13712.5
# 5518           -1304.5  ...   0.298824     10003.5     18530.0     10555.5
# 2923           -2437.0  ...   0.318793      8683.0     16810.0     12327.0
# 1490            -187.0  ...   0.218435      9704.5     15129.0     15913.5
#
#       SR_B7_lag0  class   latitude   longitude  \
# 1945      9559.5      1  46.857697   25.710457
# 5364     10134.0      0  38.626794  -79.048825
# 5518      9523.5      0  46.361019  135.365109
# 2923      9557.0      1  38.110442  -78.162188
# 1490     12139.5      1  39.357124  -79.199203
#
#                                         .geo  year
# 1945  {"type":"MultiPoint","coordinates":[]}  2022
# 5364  {"type":"MultiPoint","coordinates":[]}  2022
# 5518  {"type":"MultiPoint","coordinates":[]}  2022
# 2923  {"type":"MultiPoint","coordinates":[]}  2022
# 1490  {"type":"MultiPoint","coordinates":[]}  2022
#
# [5 rows x 69 columns]

# %%
print(len(train_set))
# Out:
# 53985

# %%
all_features = train_set.columns.drop(['year', 'system:index', 'class', 'latitude', 'longitude', '.geo', 'year'])

recent_features = ['NBR_delta_lag1', 'NBR_lag1',
       'NDMI_delta_lag1', 'NDMI_lag1', 'NDVI_delta_lag1', 'NDVI_lag1',
       'SR_B4_delta_lag1', 'SR_B4_lag1', 'SR_B5_delta_lag1', 'SR_B5_lag1',
       'SR_B6_delta_lag1', 'SR_B6_lag1', 'SR_B7_delta_lag1', 'SR_B7_lag1',
       'NBR_lag0', 'NDMI_lag0', 'NDVI_lag0', 'SR_B4_lag0', 'SR_B5_lag0',
       'SR_B6_lag0', 'SR_B7_lag0']

# %%
from sklearn.model_selection import train_test_split

X = train_set[recent_features]
y = train_set['class']

# %% [markdown]
# # Evaluate Model on Training Data via Nested-CV

# %%
def custom_year_ts_split(df, year_col):
    """Custom CV splitter for our yearly data."""
    # Get unique years and sort them
    years = sorted(df[year_col].unique())
    
    # We need at least 2 years to do one split (Train Y1 -> Val Y2)
    for i in range(1, len(years)):
        # Training set: All years up to the current split
        train_indices = df[df[year_col].isin(years[:i])].index.values
        
        # Validation set: The very next year
        val_indices = df[df[year_col] == years[i]].index.values
        yield train_indices, val_indices

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PowerTransformer, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from xgboost import XGBClassifier

# %%
xgboost_param_grid = {
    'model__max_depth': Integer(3, 5),
    'model__min_child_weight': Integer(1, 200),
    'model__subsample': Real(0.7, 1),
    'model__colsample_bylevel': Real(0.5, 1),
    'model__colsample_bynode': Real(0.5, 1),
    'model__reg_lambda': Real(0, 10),
    'model__reg_alpha': Real(0, 10)
}

# %%
xgb_pipe = Pipeline([
    ('transformer', PowerTransformer('yeo-johnson')),
    ('model', XGBClassifier(objective='binary:logistic', random_state=1, learning_rate=0.3, tree_method='hist'))
])

tuner = BayesSearchCV(
    estimator=xgb_pipe,
    cv=5,
    n_iter=32,
    refit='f1',
    search_spaces=xgboost_param_grid,
    return_train_score=True,
    random_state=1,
    scoring='f1',
)

cv_iterator = custom_year_ts_split(train_set, 'year')

xgb_results = cross_validate(
    tuner,
    X, 
    y, 
    cv=cv_iterator, 
    scoring=['f1', 'precision', 'recall'], 
    return_estimator=True,
    return_train_score=True  # Crucial for detecting overfitting
)

# %%
# Print inner-CV (5-fold) average train/test scores for each outer fold (using best inner params)
for outer_fold, outer_estimator in enumerate(xgb_results['estimator'], start=1):
    search = outer_estimator.named_steps['model'] if hasattr(outer_estimator, "named_steps") else outer_estimator
    inner_results = pd.DataFrame(search.cv_results_)
    best_idx = search.best_index_

    print(f"Outer Fold {outer_fold} Parameters - {search.best_params_}")
    mean_test = inner_results.loc[best_idx, "mean_test_score"]
    std_test = inner_results.loc[best_idx, "std_test_score"]
    print(f"Outer Fold {outer_fold} - Inner Mean Test Score:  {mean_test:.6f}")
    print(f"Outer Fold {outer_fold} - Inner Test Score STD:  {std_test:.6f}")

    if "mean_train_score" in inner_results.columns:
        mean_train = inner_results.loc[best_idx, "mean_train_score"]
        std_train = inner_results.loc[best_idx, "std_train_score"]
        print(f"Outer Fold {outer_fold} - Inner Mean Train Score: {mean_train:.6f}")
        print(f"Outer Fold {outer_fold} - Inner Train Score STD:  {std_test:.6f}")
    else:
        print(f"Outer Fold {outer_fold} - Inner Mean Train Score: not available (set return_train_score=True in BayesSearchCV)")

print('\nOverall Metrics')
print(f"Mean Test f1: {xgb_results['test_f1'].mean():.8f}")
print(f"Mean Test Precision: {xgb_results['test_precision'].mean():.8f}")
print(f"Mean Test Recall: {xgb_results['test_recall'].mean():.8f}")

print(f"Mean Train f1: {xgb_results['train_f1'].mean():.8f}")
print(f"Mean Train Precision: {xgb_results['train_precision'].mean():.8f}")
print(f"Mean Train Recall: {xgb_results['train_recall'].mean():.8f}")

print(f"Overfitting Ratio: {1-xgb_results['test_f1'].mean()/xgb_results['train_f1'].mean()}")
# Out:
# Outer Fold 1 Parameters - OrderedDict({'model__colsample_bylevel': 1.0, 'model__colsample_bynode': 1.0, 'model__max_depth': 5, 'model__min_child_weight': 1, 'model__reg_alpha': 0.0, 'model__reg_lambda': 0.0, 'model__subsample': 1.0})
# Outer Fold 1 - Inner Mean Test Score:  0.993523
# Outer Fold 1 - Inner Test Score STD:  0.000535
# Outer Fold 1 - Inner Mean Train Score: 0.999339
# Outer Fold 1 - Inner Train Score STD:  0.000535
# Outer Fold 2 Parameters - OrderedDict({'model__colsample_bylevel': 1.0, 'model__colsample_bynode': 1.0, 'model__max_depth': 5, 'model__min_child_weight': 1, 'model__reg_alpha': 0.0, 'model__reg_lambda': 0.0, 'model__subsample': 0.7})
# Outer Fold 2 - Inner Mean Test Score:  0.999354
# Outer Fold 2 - Inner Test Score STD:  0.001019
# Outer Fold 2 - Inner Mean Train Score: 0.999824
# Outer Fold 2 - Inner Train Score STD:  0.001019
#
# Overall Metrics
# Mean Test f1: 0.99991569
# Mean Test Precision: 1.00000000
# Mean Test Recall: 0.99983140
# Mean Train f1: 0.99991570
# Mean Train Precision: 1.00000000
# Mean Train Recall: 0.99983142
# Overfitting Ratio: 9.477817308756187e-09

# %%
import shap
# Re-fit the tuner on full training data to get a final best estimator for interpretation
tuner.fit(X, y)
best_pipe = tuner.best_estimator_
model = best_pipe.named_steps['model']
explainer = shap.Explainer(model)
# Transform training data for the model component
X_trans = pd.DataFrame(
    best_pipe.named_steps['transformer'].transform(X),
    columns=recent_features,
    index=X.index,
)
shap_values = explainer(X_trans)
# visualize explanations
shap.plots.beeswarm(shap_values)
shap.plots.bar(shap_values)

# %% [markdown]
# # Train Model

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
from xgboost import XGBClassifier
from sklearn.preprocessing import PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import f1_score

# %%
xgboost_param_grid = {
    'model__max_depth': Integer(3, 5),
    'model__min_child_weight': Integer (1, 200),
    'model__subsample': Real(0.7, 1),
    'model__colsample_bylevel': Real(0.5, 1),
    'model__colsample_bynode': Real(0.5, 1),
    'model__reg_lambda': Real(0, 10),
    'model__reg_alpha': Real(0, 10)
}

# %%
stage_1_pipe = Pipeline([
    ('transformer', PowerTransformer('yeo-johnson')),
    ('model', XGBClassifier(objective='binary:logistic', random_state=1, learning_rate=0.3, tree_method='hist'))])

tuner = BayesSearchCV(
    estimator=stage_1_pipe,
    cv=5,
    refit='f1',
    search_spaces=xgboost_param_grid,
    return_train_score=True,
    random_state=1,
    scoring='f1'
)

# %%
tuner.fit(X_train, y_train)
# Out:
# BayesSearchCV(cv=5,
#               estimator=Pipeline(steps=[('transformer', PowerTransformer()),
#                                         ('model',
#                                          XGBClassifier(base_score=None,
#                                                        booster=None,
#                                                        callbacks=None,
#                                                        colsample_bylevel=None,
#                                                        colsample_bynode=None,
#                                                        colsample_bytree=None,
#                                                        device=None,
#                                                        early_stopping_rounds=None,
#                                                        enable_categorical=False,
#                                                        eval_metric=None,
#                                                        feature_types=None,
#                                                        feature_weights=None,
#                                                        gamma=None,
#                                                        grow...
#                              'model__max_depth': Integer(low=3, high=5, prior='uniform', transform='normalize'),
#                              'model__min_child_weight': Integer(low=1, high=200, prior='uniform', transform='normalize'),
#                              'model__reg_alpha': Real(low=0, high=10, prior='uniform', transform='normalize'),
#                              'model__reg_lambda': Real(low=0, high=10, prior='uniform', transform='normalize'),
#                              'model__subsample': Real(low=0.7, high=1, prior='uniform', transform='normalize')})

# %%
print(tuner.best_params_)
params = {k.replace('model__', ''): v for k, v in tuner.best_params_.items()}
# Out:
# OrderedDict({'model__colsample_bylevel': 1.0, 'model__colsample_bynode': 0.5, 'model__max_depth': 5, 'model__min_child_weight': 1, 'model__reg_alpha': 4.793991507560569, 'model__reg_lambda': 4.674429133439942, 'model__subsample': 1.0})

# %%
stage_2_transformer = PowerTransformer('yeo-johnson')
stage_2_model = XGBClassifier(**params, objective='binary:logistic', random_state=1, learning_rate=0.001, early_stopping_rounds=50, eval_metric="logloss", tree_method='hist')

# %%
X_train_stage2 = stage_2_transformer.fit_transform(X_train)
X_val_stage2 = stage_2_transformer.transform(X_val)

stage_2_model.fit(
    X_train_stage2, y_train,
    eval_set=[(X_val_stage2, y_val)], # Required for early stopping
    verbose=True,                     # Shows progress
)
# Out:
# [0]	validation_0-logloss:0.69263
# [1]	validation_0-logloss:0.69205
# [2]	validation_0-logloss:0.69146
# [3]	validation_0-logloss:0.69086
# [4]	validation_0-logloss:0.69027
# [5]	validation_0-logloss:0.68967
# [6]	validation_0-logloss:0.68910
# [7]	validation_0-logloss:0.68852
# [8]	validation_0-logloss:0.68794
# [9]	validation_0-logloss:0.68736
# [10]	validation_0-logloss:0.68677
# [11]	validation_0-logloss:0.68619
# [12]	validation_0-logloss:0.68560
# [13]	validation_0-logloss:0.68503
# [14]	validation_0-logloss:0.68448
# [15]	validation_0-logloss:0.68390
# [16]	validation_0-logloss:0.68331
# [17]	validation_0-logloss:0.68272
# [18]	validation_0-logloss:0.68214
# [19]	validation_0-logloss:0.68156
# [20]	validation_0-logloss:0.68099
# [21]	validation_0-logloss:0.68042
# [22]	validation_0-logloss:0.67986
# [23]	validation_0-logloss:0.67931
# [24]	validation_0-logloss:0.67876
# [25]	validation_0-logloss:0.67819
# [26]	validation_0-logloss:0.67762
# [27]	validation_0-logloss:0.67704
# [28]	validation_0-logloss:0.67649
# [29]	validation_0-logloss:0.67594
# [30]	validation_0-logloss:0.67541
# [31]	validation_0-logloss:0.67486
# [32]	validation_0-logloss:0.67429
# [33]	validation_0-logloss:0.67373
# [34]	validation_0-logloss:0.67317
# [35]	validation_0-logloss:0.67261
# [36]	validation_0-logloss:0.67206
# [37]	validation_0-logloss:0.67151
# [38]	validation_0-logloss:0.67094
# [39]	validation_0-logloss:0.67038
# [40]	validation_0-logloss:0.66982
# [41]	validation_0-logloss:0.66927
# [42]	validation_0-logloss:0.66872
# [43]	validation_0-logloss:0.66817
# [44]	validation_0-logloss:0.66761
# [45]	validation_0-logloss:0.66705
# [46]	validation_0-logloss:0.66651
# [47]	validation_0-logloss:0.66596
# [48]	validation_0-logloss:0.66540
# [49]	validation_0-logloss:0.66486
# [50]	validation_0-logloss:0.66432
# [51]	validation_0-logloss:0.66377
# [52]	validation_0-logloss:0.66324
# [53]	validation_0-logloss:0.66269
# [54]	validation_0-logloss:0.66215
# [55]	validation_0-logloss:0.66161
# [56]	validation_0-logloss:0.66107
# [57]	validation_0-logloss:0.66053
# [58]	validation_0-logloss:0.65998
# [59]	validation_0-logloss:0.65944
# [60]	validation_0-logloss:0.65890
# [61]	validation_0-logloss:0.65836
# [62]	validation_0-logloss:0.65784
# [63]	validation_0-logloss:0.65732
# [64]	validation_0-logloss:0.65680
# [65]	validation_0-logloss:0.65627
# [66]	validation_0-logloss:0.65573
# [67]	validation_0-logloss:0.65521
# [68]	validation_0-logloss:0.65468
# [69]	validation_0-logloss:0.65415
# [70]	validation_0-logloss:0.65363
# [71]	validation_0-logloss:0.65311
# [72]	validation_0-logloss:0.65259
# [73]	validation_0-logloss:0.65206
# [74]	validation_0-logloss:0.65154
# [75]	validation_0-logloss:0.65102
# [76]	validation_0-logloss:0.65051
# [77]	validation_0-logloss:0.64998
# [78]	validation_0-logloss:0.64946
# [79]	validation_0-logloss:0.64895
# [80]	validation_0-logloss:0.64843
# [81]	validation_0-logloss:0.64794
# [82]	validation_0-logloss:0.64744
# [83]	validation_0-logloss:0.64693
# [84]	validation_0-logloss:0.64642
# [85]	validation_0-logloss:0.64590
# [86]	validation_0-logloss:0.64541
# [87]	validation_0-logloss:0.64490
# [88]	validation_0-logloss:0.64439
# [89]	validation_0-logloss:0.64387
# [90]	validation_0-logloss:0.64335
# [91]	validation_0-logloss:0.64284
# [92]	validation_0-logloss:0.64233
# [93]	validation_0-logloss:0.64182
# [94]	validation_0-logloss:0.64132
# [95]	validation_0-logloss:0.64082
# [96]	validation_0-logloss:0.64031
# [97]	validation_0-logloss:0.63982
# [98]	validation_0-logloss:0.63933
# [99]	validation_0-logloss:0.63882
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=1.0, colsample_bynode=0.5,
#               colsample_bytree=None, device=None, early_stopping_rounds=50,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.001, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
best_round = stage_2_model.best_iteration
print(best_round)
print(stage_2_model.best_score)
# Out:
# 99
# 0.6388178873229956

# %%
final_pipe = Pipeline([
    ('transformer', PowerTransformer('yeo-johnson')),
    ('model', XGBClassifier(**params, objective='binary:logistic', random_state=1, learning_rate=0.001, n_estimators=best_round, tree_method='hist'))])
final_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer', PowerTransformer()),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=1.0, colsample_bynode=0.5,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.001, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=5,
#                                max_leaves=None, min_child_weight=1, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=99, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
print(f1_score(y, final_pipe.predict(X)))
# Out:
# 0.8749056421174877

# %%
import shap
explainer = shap.Explainer(final_pipe['model'])
# Transform training data for the model component
X_trans = pd.DataFrame(
    final_pipe.named_steps['transformer'].transform(X_train),
    columns=recent_features,
    index=X_train.index,
)
shap_values = explainer(X_trans)
# visualize explanations
shap.plots.beeswarm(shap_values)
shap.plots.bar(shap_values)

# %%
print(len(X))
# Out:
# 53985

# %% [markdown]
# # Test On Holdout Set From the Same Region

# %%
appalachia_test = prepare_data(pd.read_csv(f"datasets/post_pivot/plus_one/expanded_class/types/temperate/appalachia_test_2025.csv"), 2025)
carpathians_test = prepare_data(pd.read_csv("datasets/post_pivot/plus_one/expanded_class/types/temperate/carpathians_test_2025.csv"), 2025)
fareast_test = prepare_data(pd.read_csv("datasets/post_pivot/plus_one/expanded_class/types/temperate/fareast_test_2025.csv"), 2025)

print(len(appalachia_test))
print(len(carpathians_test))
print(len(fareast_test))
# Out:
# 6000
# 6000
# 5999

# %%
X_test_appalachia = appalachia_test[recent_features]
y_test_appalachia = appalachia_test['class']
X_test_carpathians = carpathians_test[recent_features]
y_test_carpathians = carpathians_test['class']
X_test_fareast = fareast_test[recent_features]
y_test_fareast = fareast_test['class']
print(y_test_carpathians.value_counts())
# Out:
# class
# 1    3000
# 0    3000
# Name: count, dtype: int64

# %%
from sklearn.metrics import precision_score, recall_score

print("appalachia Test")
y_test_appalachia_pred = final_pipe.predict(X_test_appalachia)
print(f"f1: {f1_score(y_test_appalachia, y_test_appalachia_pred)}")
print(f"precision: {precision_score(y_test_appalachia, y_test_appalachia_pred)}")
print(f"recall: {recall_score(y_test_appalachia, y_test_appalachia_pred)}")

print("fareast Test")
y_test_fareast_pred = final_pipe.predict(X_test_fareast)
print(f"f1: {f1_score(y_test_fareast, y_test_fareast_pred)}")
print(f"precision: {precision_score(y_test_fareast, y_test_fareast_pred)}")
print(f"recall: {recall_score(y_test_fareast, y_test_fareast_pred)}")

print("carpathians Test")
y_test_carpathians_pred = final_pipe.predict(X_test_carpathians)
print(f"f1: {f1_score(y_test_carpathians, y_test_carpathians_pred)}")
print(f"precision: {precision_score(y_test_carpathians, y_test_carpathians_pred)}")
print(f"recall: {recall_score(y_test_carpathians, y_test_carpathians_pred)}")

print("All Together Test")
X_test = pd.concat([X_test_appalachia, X_test_fareast, X_test_carpathians])
y_test = pd.concat([y_test_appalachia, y_test_fareast, y_test_carpathians])
y_test_pred = final_pipe.predict(X_test)
print(f"f1: {f1_score(y_test, y_test_pred)}")
print(f"precision: {precision_score(y_test, y_test_pred)}")
print(f"recall: {recall_score(y_test, y_test_pred)}")
# Out:
# appalachia Test
# f1: 0.8748975241842925
# precision: 0.8609228783478542
# recall: 0.8893333333333333
# fareast Test
# f1: 0.8691489361702127
# precision: 0.928409090909091
# recall: 0.817
# carpathians Test
# f1: 0.857357075913777
# precision: 0.9794432548179871
# recall: 0.7623333333333333
# All Together Test
# f1: 0.8675178634180626
# precision: 0.91726529601189
# recall: 0.8228888888888889

# %% [markdown]
# # Test on New Regions

# %%
valdivian_test = prepare_data(pd.read_csv(f"datasets/post_pivot/plus_one/expanded_class/types/temperate/valdivian_test_2025.csv"), 2025)

# %%
X_test_valdivian = valdivian_test[recent_features]
y_test_valdivian = valdivian_test['class']
print(y_test_valdivian.value_counts())
# Out:
# class
# 1    3000
# 0    3000
# Name: count, dtype: int64

# %%
print("Valdivian Test")
y_test_valdivian_pred = final_pipe.predict(X_test_valdivian)
print(f"f1: {f1_score(y_test_valdivian, y_test_valdivian_pred)}")
print(f"precision: {precision_score(y_test_valdivian, y_test_valdivian_pred)}")
print(f"recall: {recall_score(y_test_valdivian, y_test_valdivian_pred)}")
# Out:
# Valdivian Test
# f1: 0.7723205408629946
# precision: 0.9571217348447512
# recall: 0.6473333333333333

# %% [markdown]
# Temperate model succeeds, though not quite as good on the Valdivian...
